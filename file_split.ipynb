# %%
import os
import shutil
file_list = os.listdir("./train75/train")

# %%
file_list[0].split(".")
# Out:
# ['3403540-75', 'jpg']

# %%
os.path.splitext(file_list[1])
# Out:
# ('3403540-75', '.xml')

# %%
after_list = []

# %%
file_list[7].split(".")[0].replace("_jpg",'.xml')
# Out:
# '3404277-75.xml'

# %%
len(file_list)
# Out:
# 2240

# %%
for i in range(len(file_list)):
    if (file_list[i].split(".")[3] =='jpg'):
        after_list.append(file_list[i].split(".")[0].replace("_","."))
    else:
        after_list.append(file_list[i].split(".")[0].replace("_jpg",'.xml'))
# Out:
# 2240

# %%
file_list[0]
# Out:
# '3403540-75_jpg.rf.3ad3e9917bbd47a99282bf6ffde73200.jpg'

# %%
after_list[0]
# Out:
# '3403540-75.jpg'

# %%
for i in range(len(file_list)):
    file_oldname = os.path.join("./train75/train",f"{file_list[i]}")
    file_newname = os.path.join("./train75/train",f"{after_list[i]}")

    newFileName = shutil.move(file_oldname,file_newname)
    print(newFileName)
# Out:
# ./train75/train\3403540-75.jpg
# ./train75/train\3403540-75.xml
# ./train75/train\3403841-75.jpg
# ./train75/train\3403841-75.xml
# ./train75/train\3403871-75.jpg
# ./train75/train\3403871-75.xml
# ./train75/train\3404277-75.jpg
# ./train75/train\3404277-75.xml
# ./train75/train\3404349-75.jpg
# ./train75/train\3404349-75.xml
# ./train75/train\3404385-75.jpg
# ./train75/train\3404385-75.xml
# ./train75/train\3404444-75.jpg
# ./train75/train\3404444-75.xml
# ./train75/train\3404512-75.jpg
# ./train75/train\3404512-75.xml
# ./train75/train\3404655-75.jpg
# ./train75/train\3404655-75.xml
# ./train75/train\3404745-75.jpg
# ./train75/train\3404745-75.xml
# ./train75/train\3404766-75.jpg
# ./train75/train\3404766-75.xml
# ./train75/train\3404821-75.jpg
# ./train75/train\3404821-75.xml
# ./train75/train\3404862-75.jpg
# ./train75/train\3404862-75.xml
# ./train75/train\3404954-75.jpg
# ./train75/train\3404954-75.xml
# ./train75/train\3404995-75.jpg
# ./train75/train\3404995-75.xml
# ...

# %%
file_list = os.listdir("./valid75/valid")

# %%
for i in range(len(file_list)):
    if (file_list[i].split(".")[3] =='jpg'):
        after_list.append(file_list[i].split(".")[0].replace("_","."))
    else:
        after_list.append(file_list[i].split(".")[0].replace("_jpg",'.xml'))

# %%
print(len(file_list),len(after_list))
# Out:
# 280 280

# %%
for i in range(len(file_list)):
    file_oldname = os.path.join("./valid75/valid",f"{file_list[i]}")
    file_newname = os.path.join("./valid75/valid",f"{after_list[i]}")

    newFileName = shutil.move(file_oldname,file_newname)
    print(newFileName)
# Out:
# ./valid75/valid\3414142-75.jpg
# ./valid75/valid\3414142-75.xml
# ./valid75/valid\3414264-75.jpg
# ./valid75/valid\3414264-75.xml
# ./valid75/valid\3414393-75.jpg
# ./valid75/valid\3414393-75.xml
# ./valid75/valid\3414430-75.jpg
# ./valid75/valid\3414430-75.xml
# ./valid75/valid\3415284-75.jpg
# ./valid75/valid\3415284-75.xml
# ./valid75/valid\3415359-75.jpg
# ./valid75/valid\3415359-75.xml
# ./valid75/valid\3415638-75.jpg
# ./valid75/valid\3415638-75.xml
# ./valid75/valid\3415851-75.jpg
# ./valid75/valid\3415851-75.xml
# ./valid75/valid\3416234-75.jpg
# ./valid75/valid\3416234-75.xml
# ./valid75/valid\3416425-75.jpg
# ./valid75/valid\3416425-75.xml
# ./valid75/valid\3416449-75.jpg
# ./valid75/valid\3416449-75.xml
# ./valid75/valid\3416517-75.jpg
# ./valid75/valid\3416517-75.xml
# ./valid75/valid\3416532-75.jpg
# ./valid75/valid\3416532-75.xml
# ./valid75/valid\3416584-75.jpg
# ./valid75/valid\3416584-75.xml
# ./valid75/valid\3417081-75.jpg
# ./valid75/valid\3417081-75.xml
# ...

# %%
file_list[0][-1]=='l'
# Out:
# False

# %%
import shutil

src = "./train75/train/"
dsrc = "./train75/train/labels/"
for i in range(len(file_list)):
    if(file_list[i][-1]=='l'):
        shutil.move(src+file_list[i],dsrc+file_list[i])

# %%
import shutil

src = "./train75/train/"
dsrc = "./train75/train/images/"
for i in range(len(file_list)):
    if(file_list[i][-1]=='g'):
        shutil.move(src+file_list[i],dsrc+file_list[i])

# %%
file_list = os.listdir("./valid75/valid")

# %%
import shutil

src = "./valid75/valid/"
dsrc = "./valid75/valid/labels/"
for i in range(len(file_list)):
    if(file_list[i][-1]=='l'):
        shutil.move(src+file_list[i],dsrc+file_list[i])

# %%
import shutil

src = "./valid75/valid/"
dsrc = "./valid75/valid/images/"
for i in range(len(file_list)):
    if(file_list[i][-1]=='g'):
        shutil.move(src+file_list[i],dsrc+file_list[i])
