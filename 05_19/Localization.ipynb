# %% [markdown]
# 2. **Localization & Size value**
#     1. 클래스별 객체(bbox)의 위치 정보(좌상 좌하 우상 우하 가운데) 분포

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os

# %%
data = pd.read_csv('../data(05_18).csv')
data
# Out:
#       imagePath  label  Shape_num                                 points_1  \
# 0       3403540   pack          1              [926.4466239999999, 1682.1]
# 1       3403580   pack          2              [920.1440959999999, 1543.5]
# 2       3403580   pack          2          [891.78272, 1890.0020160000001]
# 3       3403658    can          1              [998.9234240000001, 1701.0]
# 4       3403788  glass          1  [1434.7829220270894, 972.0860832255465]
# ...         ...    ...        ...                                      ...
# 58057   t3_0029    can          6                           [721.0, 375.0]
# 58058   t3_0029   pack          6                           [591.0, 356.0]
# 58059   t3_0029  glass          6              [451.00000000000006, 508.0]
# 58060   t3_0030    pet          2                           [706.0, 555.0]
# 58061   t3_0030    pet          2                           [855.0, 216.0]
#
#                                 points_2
# ...

# %%
image_list = data['imagePath'].unique()

# %%
path = 'E:/reusable-trash-images/selectstar-reusable-trash-image'
image_path = path+'/'+image_list[1]+".jpg"
image = cv2.imread(image_path, cv2.IMREAD_COLOR)
image2 = image.copy()
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
image.shape
# Out:
# (4032, 2272, 3)

# %%
data['points_1'][0:1].values[0]
# Out:
# '[926.4466239999999, 1682.1]'

# %% [markdown]
# (4032, 2272, 3)

# %%
image = cv2.line(image,(1136,0),(1136,4032),(255,0,0),10)
image = cv2.line(image,(0,2016),(2272,2016),(255,0,0),10)
image = cv2.rectangle(image,(920,1543),(1462,1968),(0,0,255),10)
image = cv2.rectangle(image,(891,1890),(1317,2447),(0,0,255),10)
image = cv2.circle(image,(1191,1755),10, (0,255,0),thickness=20)

# %%
plt.imshow(image)
plt.show()
