# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
test = pd.read_csv('./test.csv', index_col=False)
test
# Out:
#         imagePath    label  Shape_num  width  height  point1_x  point1_y  \
# 0         3427680  plastic          1   2268    4032       888      1729
# 1         3427699  plastic          1   2268    4032       983      1436
# 2         3427732  plastic          1   2268    4032       891      1317
# 3         3427756  plastic          1   2268    4032       961      1427
# 4         3428134  plastic          1   2268    4032       863      1191
# ..            ...      ...        ...    ...     ...       ...       ...
# 135       4998465      can          1   2268    4032       961      1653
# 136       5056399      can          1   2268    4032       873      1600
# 137       5072603      can          1   2268    4032       866      2007
# 138       5077990      can          1   2268    4032       887      1445
# 139  custom_00187      can          1   2268    4032       802      1744
#
#      point2_x  point2_y  ascept_ratio  BgMeanR  BgMeanG  BgMeanB
# ...

# %%
test['label'].value_counts()
# Out:
# plastic    20
# paper      20
# pack       20
# vinyl      20
# glass      20
# pet        20
# can        20
# Name: label, dtype: int64
