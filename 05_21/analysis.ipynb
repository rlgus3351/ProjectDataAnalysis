# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../data(05_22).csv', index_col=False)
# Out:
# C:\Users\smhrd\AppData\Local\Temp\ipykernel_24140\3601819350.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../data(05_22).csv', index_col=False)

# %%
ones =data[data.loc[:,'Shape_num']==16]

# %%
ones
# Out:
#       imagePath    label  Shape_num     point1_x     point1_y     point2_x  \
# 6074    3435746     pack         16   619.480519  1309.090909   815.999760
# 6075    3435746     pack         16   618.129870  1060.987013   816.233766
# 6076    3435746     pack         16   618.077922  1078.467532   816.181818
# 6077    3435746     pack         16   618.675325  1095.298701   816.779221
# 6078    3435746     pack         16   619.272727  1112.129870   817.376623
# 6079    3435746     pack         16   620.519481  1129.610390   818.623377
# 6080    3435746     pack         16   621.766234  1146.441558   819.870130
# 6081    3435746     pack         16   621.714286  1161.974026   819.818182
# 6082    3435746     pack         16   620.363636  1178.155844   818.467532
# 6083    3435746     pack         16   620.961039  1191.740260   819.064935
# 6084    3435746     pack         16   620.909091  1209.870130   819.012987
# ...

# %%
ones[ones['label']=='pack'].describe()
# Out:
#        Shape_num    point1_x     point1_y    point2_x     point2_y  \
# count       16.0   16.000000    16.000000   16.000000    16.000000
# mean        16.0  620.349026  1185.608766  818.353881  1219.162378
# std          0.0    1.447664    78.141774    1.560827   105.846618
# min         16.0  618.077922  1060.987013  815.999760  1083.116883
# 25%         16.0  619.370130  1125.240260  817.227273  1147.370130
# 50%         16.0  620.441558  1184.948052  818.545455  1207.077922
# 75%         16.0  621.149351  1246.279221  819.253247  1268.409091
# max         16.0  622.753247  1309.090909  820.857143  1514.000640
#
#        AllPixelMeanR  AllPixelMeanG  AllPixelMeanB  bBoxMeanR   bBoxMeanG  \
# count           16.0           16.0           16.0    16.0000   16.000000
# mean           115.0          114.0          108.0   240.9375   61.500000
# std              0.0            0.0            0.0    15.0531   35.985182
# ...
